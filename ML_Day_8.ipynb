# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.normal(170,10,250)
print(type(x))
#print(x)

plt.hist(x)
plt.show()
# Out:
# <class 'numpy.ndarray'>

# %%
y = [35,25,25,15]
lab = ["a","b","c","d"]
col = ["orange", "hotpink","red","magenta"]
plt.pie(y, labels = lab, startangle = 90, colors = col, shadow = True, explode = (0,0,0,0.1), autopct = "%1.1f%%")
plt.show()
